# %%
import pandas as pd

# %%
df=pd.read_csv("Housing_Price_Data_mine.csv")

# %%
df
# Out:
#      area     price
# 0    7420  13300000
# 1    8960  12250000
# 2    9960  12250000
# 3    7500  12215000
# 4    7420  11410000
# ..    ...       ...
# 540  3000   1820000
# 541  2400   1767150
# 542  3620   1750000
# 543  2910   1750000
# 544  3850   1750000
#
# [545 rows x 2 columns]

# %%
x=df[["area"]]
y=df.price

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
model.fit(x,y)
# Out:
# LinearRegression()

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
op=model.predict([[7000]])
op
# Out:
# array([5621132.74230591])

# %%
op[0]
# Out:
# np.float64(5621132.742305914)

# %%
import pickle

# %%
pickle.dump(model,open("area.pkl","wb"))

# %%
import streamlit as st

# %%
st
# Out:
# <module 'streamlit' from 'C:\\Users\\Raj Gaurav\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\site-packages\\streamlit\\__init__.py'>
